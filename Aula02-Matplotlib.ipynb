# %% [markdown]
# # Matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Nós podemos usar um pacote para melhorar o aspecto das figuras.
# Aqui usaremos `SciencePlots` (https://github.com/garrettj403/SciencePlots)

# %%
# plt.style.use(['science','notebook','grid'])

# %% [markdown]
# ## Gerando os dados a serem plotados

# %%
x = np.arange(0,48,0.1)
y = 298 + 0.5*np.sin(2*np.pi*x/2.0) - 5*np.cos(2*np.pi*x/24.0) + 0.1*np.random.randn(x.size)

# %%
plt.scatter(x,y)
plt.plot(x,y,color='red')

# %% [markdown]
# ## Nome dos eixos

# %%
plt.plot(x,y)
plt.xlabel('Tempo (h)')
plt.ylabel('Temperatura (K)')
# Out:
# Text(0, 0.5, 'Temperatura (K)')

# %% [markdown]
# ## Adicionando Legenda

# %%
plt.plot(x,y,label='Exp.')
plt.xlabel('Tempo (h)')
plt.ylabel('Temperatura (K)')
plt.legend(loc='upper right')

# %% [markdown]
# ## Adicionando outro gráfico

# %%
y2 = 298 + 0.5*np.sin(2*np.pi*x/2.0) - 5*np.cos(2*np.pi*x/24.0)
y3 = 298 - 5*np.cos(2*np.pi*x/24.0)

# %%
plt.scatter(x,y,label='Exp.')
plt.plot(x,y2,'k-',label='Teo.')
plt.plot(x,y3,'C2--',label='Saz.')
plt.xlabel('Tempo (h)')
plt.ylabel('Temperatura (K)')
plt.legend(loc='upper right')

# %%
plt.scatter(x,y,marker='o',edgecolors='C0',facecolors='None',label='Exp.')
plt.plot(x,y2,'k-',label='Teo.')
plt.plot(x,y3,'C2--',label='Saz.')
plt.xlabel('Tempo (h)')
plt.ylabel('Temperatura (K)')
plt.legend(loc='upper right')

# %% [markdown]
# ## Limites dos eixos

# %%
plt.scatter(x,y,marker='o',edgecolors='C0',facecolors='None',label='Exp.')
plt.plot(x,y2,'k-',label='Teo.')
plt.plot(x,y3,'C2--',label='Saz.')
plt.xlabel('Tempo (h)')
plt.ylabel('Temperatura (K)')
plt.legend(loc='upper right')
plt.xlim(0,24)
plt.ylim(None,304)
# Out:
# (291.8622747134971, 304.0)

# %% [markdown]
# ## Tamanho da figura

# %%
fig = plt.figure(figsize=(8, 6))

plt.scatter(x,y,marker='o',edgecolors='C0',facecolors='None',label='Exp.')
plt.plot(x,y2,'k-',label='Teo.')
plt.plot(x,y3,'C2--',label='Saz.')
plt.xlabel('Tempo (h)')
plt.ylabel('Temperatura (K)')
plt.legend(loc='upper right')
plt.xlim(0,24)
plt.ylim(None,304)
# Out:
# (291.8622747134971, 304.0)
